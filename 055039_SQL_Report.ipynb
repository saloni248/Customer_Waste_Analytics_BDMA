# %% [markdown]
# # E-Commerce Consumer Waste Analytics Database
# ## Project Report
#
# ## "Consumer Waste Analytics: Designing and Implementing a Relational Database for Waste Management Insights"
#
# ### Submitted to:
# **Prof. Amarnath Mitra**
#
# ### Submitted by:
# **055021 - Khushi Kalra**
# **055039 - Saloni Gupta**

# %% [markdown]
# # Customer Waste Analytics – Database Functionality and Stress Testing
#
# ## 📊 Project Overview
# This project focuses on building a **Customer Waste Analytics** database to track product returns, environmental impact, and supplier contributions. The database is tested for **functionality and performance** using various SQL queries, including **data insertion, updates, deletions, aggregations, and complex joins**.
#
# Additionally, **stress testing** is conducted to evaluate the database’s efficiency under **high query loads** and determine whether it complies with **First Normal Form (1NF)**.
#
# The **Entity-Relationship Diagram (ERD)** provides a structured representation of the database schema.
#
# ## 📊 Database Tables
# The database consists of the following tables:
#
# 1. **Customers** – Stores customer details
# 2. **Products** – Contains product information
# 3. **Orders** – Tracks customer orders
# 4. **OrderDetails** – Provides itemized order details
# 5. **EnvironmentalImpactSummary** – Summarizes environmental impact for products
# 6. **Suppliers** – Stores supplier details and product sourcing information
# 7. **Inventory** – Manages stock levels and supplier relationships
# 8. **Recommendations** – Stores suggested actions based on waste data

# %% [markdown]
# ## 🎯**ERD Diagram**

# %% [markdown]
# ![Blank diagram.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 🎯**Project Objectives**
#
# ## **1. Database Design and Implementation**
# - Develop a **relational database** for a **Customer Waste Analytics** system with **well-defined tables, relationships, and constraints** to ensure **data integrity, consistency, and efficiency**.
# - Implement **foreign key constraints** to maintain **referential integrity** between tables such as **Orders, Products, WasteMetrics, Suppliers, and Inventory**.
#
# ## **2. Data Insertion and Realism**
# - Populate the database with **realistic and meaningful data**, including **customer details, product names, return reasons, supplier ratings, stock levels, and environmental impact metrics**.
# - Ensure data consistency across all tables while adhering to **foreign key constraints**.
# - Generate **dummy data** in bulk for **stress testing** to simulate **real-world scenarios**.
#
# ## **3. Data Retrieval and Analysis**
# - Execute **complex SQL queries** for **data retrieval, aggregation, and analysis**, including:
#   - **Customer return trends** and **waste analytics**
#   - **Environmental impact assessments** based on product returns
#   - **Supplier performance evaluation**
#   - **Inventory stock analysis** and **reorder predictions**
#   - **Recommendations for waste reduction and sustainability**
# - Use **JOIN operations, subqueries, and indexing** to optimize query performance.
#
# ## **4. Normalization and Integrity Check**
# - **Verify First Normal Form (1NF)** by ensuring:
#   - No **duplicate columns** or **repeating groups** in any table.
#   - Every field contains **atomic data** (indivisible values).
#   - Each column contains **only one type of data** (e.g., no lists or multiple values in a single field).
# - Identify and eliminate **data redundancy** while maintaining **data accuracy** and **efficiency**.
#
# ## **5. Performance Testing and Optimization**
# - Conduct **stress testing** by inserting, updating, and deleting **large datasets** to evaluate system performance.
# - Execute **high-load queries** involving multiple **JOINs, aggregations, and filtering** to assess database response time under pressure.
# - Optimize **indexes, query execution plans, and storage techniques** to improve efficiency.

# %% [markdown]
# # **3. SQL Queries**
#
# The performed queries include **Create, Retrieve, Update, Delete (CRUD), and Aggregation**.
#
# - **Create**: Defines tables and relationships.
# - **Retrieve**: Extracts insights using SELECT and JOINs.
# - **Update**: Modifies records for accuracy.
# - **Delete**: Removes outdated data.
# - **Aggregation**: Computes totals, averages, and key metrics.
#
# These queries ensure **data integrity, efficiency, and meaningful analytics**.

# %% [markdown]
# # 📌Create (Data Insertion)

# %% [markdown]
# ###A. Inserting data into tables

# %% [markdown]
# ![Screenshot 2025-03-16 002453.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Retrieve

# %% [markdown]
# ### 1. **Problem Statement**: Retrieve all customers from the 'North' region with a loyalty score above 80

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.**Problem Statement**:  Get the top 5 most expensive products along with their category and price

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3. **Problem Statement**:  Retrieve customers who have purchased electronics and have an average spending above ₹30,000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4. **Problem Statement**:  Retrieve order and inventory details by joining on ProductID

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 📌Aggregation

# %% [markdown]
# ## 1. Total Sales Revenue Per Month
# ### **Problem Statement:** Retrieve total sales revenue for each month

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Average Order Quantity Per Product
# ### **Problem Statement:** Find the average number of units ordered per product:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Total Stock Per Storage Location
# ### **Problem Statement:** Retrieve total inventory stock at each storage location:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Top 5 Best-Selling Products
# ### **Problem Statement:** Find the top 5 products with the highest total quantity sold:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. Number of Orders Per Customer
# ### **Problem Statement:** Retrieve the total number of orders placed by each customer:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 6. Total Revenue Per Customer
# ### **Problem Statement:** Retrieve the total spending of each customer:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 7. Monthly Inventory Consumption Rate
# ### **Problem Statement:** Find how much inventory is used each month:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 8. Average Stock Level Per Product Category
# ### **Problem Statement:** Find the average stock level for each product category:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 📌Update

# %% [markdown]
# ## 1. Update Stock Levels After an Order
# ### **Problem Statement:** Decrease inventory stock when an order is placed:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Apply a Discount to All Orders Above ₹5000
# ### **Problem Statement:** Give a 10% discount on orders where the total amount is above ₹5000:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Mark Customers as "Premium" Based on Spending
# ### **Problem Statement:** Set CustomerType as 'Premium' for customers who have spent more than ₹50,000:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Increase Product Price by 5% for Low Stock Items
# ### **Problem Statement:** If an item has a stock level below 50, increase its price by 5%.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 📌Delete

# %% [markdown]
# ### 1. Delete customers who haven't placed an order in the last 2 years

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. Delete old, unshipped orders that are more than 1 year old

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 📌 Normalization Process & Data Integrity

# %% [markdown]
# ### 4.1. Check for Repeating Groups (Comma-Separated Values)
# If any column contains multiple values (e.g., StorageLocation has "Warehouse A, Warehouse B"), we can check for commas or other delimiters:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Since this query does not returns rows, then StorageLocation does not violates 1NF and needs not to be normalized.

# %% [markdown]
# ### 4.2. Check for Non-Atomic Values (Multivalued Attributes)
# To ensure that each attribute contains only a single atomic value, you can use CHAR_LENGTH() to find unusually long text:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Since no rows are returned, they might not contain multiple values in one column.

# %% [markdown]
# ### 4.3. Check for Duplicate Columns (Improper Repeating Groups)
#  If your schema had columns like StorageLocation1, StorageLocation2, etc., it would violate 1NF. To check if multiple similar columns exist:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4.4. Validate Primary Key (Ensuring Unique Rows)
# Since InventoryID is the Primary Key, check if it enforces uniqueness:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 📊 Database Analysis Report
#
# ## 5. Observations and Findings
#
# ### 🔍 Data Integrity Checks:
# - All tables were tested for duplicate rows using a **one-table approach**.
# - The results confirmed that **total row counts matched unique row counts** for every table, indicating the **absence of duplicate records**.
#
# ### ✅ Normalization Check (1NF):
# - The database follows the **First Normal Form (1NF)** principles:
#   - Each table has a **primary key** that uniquely identifies each record.
#   - All columns contain **atomic values** with no repeating groups or arrays.
#   - Columns contain **data of a single type** and hold only **one value per field**.
#
# ### 🔗 Data Consistency and Referential Integrity:
# - **Foreign key relationships** were tested and verified to maintain **referential integrity**.
# - **Update and delete operations** were performed safely without violating foreign key constraints.
# - Proper **cascading of changes** was observed, ensuring that **child records were correctly updated or deleted** when the parent record was modified or removed.
#
# ### 🔄 CRUD Operations:
# - The database was tested for **Create, Read, Update, and Delete (CRUD) operations**, including **aggregation queries**.

# %% [markdown]
# ## 📌 Managerial Insights & Recommendations
#
# ### 🔍 Key Business Insights
#
# 1️⃣ **Customer Segmentation & Retention:**
#    - By analyzing the `Orders` and `Customers` tables, we identified **high-value customers** (CustomerType = 'Premium') based on their total spending.
#    - **Recommendation:** Implement loyalty programs or exclusive offers for these customers to enhance retention.
#
# 2️⃣ **Inventory Optimization:**
#    - The `Inventory` and `Orders` tables indicate stock movement patterns, helping in demand forecasting.
#    - **Recommendation:** Automate stock replenishment based on historical sales trends to avoid **stockouts** and **overstocking**.
#
# 3️⃣ **Operational Efficiency & Delivery Management:**
#    - Delayed orders (`DeliveryStatus = 'Delayed'`) were identified using the `Orders` table, particularly for shipments exceeding **7 days**.
#    - **Recommendation:** Strengthen supply chain partnerships and optimize **ShippingDays** to minimize delays.
#
# 4️⃣ **Revenue Growth through Pricing Strategy:**
#    - Analysis of `TotalAmount` in the `Orders` table allowed for dynamic pricing insights.
#    - **Recommendation:** Offer **discounts on bulk purchases** and adjust pricing for **low-demand products** to maximize revenue.
#
# ### 📈 Strategic Recommendations
#
# ✔ **Enhance Data-Driven Decision-Making:**
#    - Implement **real-time dashboards** integrating `Orders`, `Inventory`, and `Customers` tables for **faster insights**.
#
# ✔ **Strengthen Fraud Detection Measures:**
#    - Monitor unusual activities in the `Transactions` table to detect **suspicious orders** and prevent fraud.
#
# ✔ **Improve Customer Experience:**
#    - Utilize customer feedback from `Reviews` or `SupportTickets` tables to improve service quality and response time.
#
# By leveraging structured **data analysis, automation, and strategic decision-making**, businesses can **enhance efficiency, optimize inventory, and improve customer satisfaction.** 🚀

# %% [markdown]
# ## 🎯 Conclusion
#
# The database has been **thoroughly analyzed and tested** to ensure compliance with **First Normal Form (1NF)** principles. The key takeaways from the analysis include:
#
# - **✅ Data Integrity**: No duplicate records were found, ensuring clean and accurate data.
# - **🔗 Referential Integrity**: Foreign key relationships were validated, preventing orphan records and maintaining data consistency.
# - **📊 CRUD Operations**: The database successfully handled **Create, Read, Update, and Delete** queries, including aggregation functions, without any inconsistencies.
# - **🚀 Structural Efficiency**:
#   - Data is **atomic** with no **repeating groups or redundancies**.
#   - Proper constraints ensure **safe updates and deletions**.
#   - Transactions maintain consistency without violating integrity rules.
#
# The **database is well-structured, optimized, and normalized to 1NF**, making it **scalable, reliable, and efficient** for further data operations and business applications. ✅
